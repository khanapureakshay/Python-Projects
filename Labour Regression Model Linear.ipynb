# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#pip install pyforest
#import pyforest

# %%
lab=pd.read_csv(r'C:\Users\AKSHAY\Downloads\Linear_Regn_LabourData.csv')
lab
# Out:
#        Age          Eduacation      Race         Hisp MaritalStatus  Nodeg  \
# 0       45  LessThanHighSchool  NotBlack  NotHispanic       Married      1
# 1       21        Intermediate  NotBlack  NotHispanic    NotMarried      0
# 2       38          HighSchool  NotBlack  NotHispanic       Married      0
# 3       48  LessThanHighSchool  NotBlack  NotHispanic       Married      1
# 4       18  LessThanHighSchool  NotBlack  NotHispanic       Married      1
# ...    ...                 ...       ...          ...           ...    ...
# 15987   22          HighSchool     black  NotHispanic    NotMarried      0
# 15988   20          HighSchool     black  NotHispanic       Married      0
# 15989   37          HighSchool  NotBlack  NotHispanic    NotMarried      0
# 15990   47  LessThanHighSchool  NotBlack  NotHispanic       Married      1
# 15991   40  LessThanHighSchool  NotBlack  NotHispanic    NotMarried      1
#
#        Earnings_1974  Earnings_1975  Earnings_1978
# ...

# %%
lab.isna().sum()
# Out:
# Age              0
# Eduacation       0
# Race             0
# Hisp             0
# MaritalStatus    0
# Nodeg            0
# Earnings_1974    0
# Earnings_1975    0
# Earnings_1978    0
# dtype: int64

# %%
lab.describe()
# Out:
#                 Age         Nodeg  Earnings_1974  Earnings_1975  Earnings_1978
# count  15992.000000  15992.000000   15992.000000   15992.000000   15992.000000
# mean      33.225238      0.295835   14016.800304   13650.803376   14846.659673
# std       11.045216      0.456432    9569.795893    9270.403225    9647.391524
# min       16.000000      0.000000       0.000000       0.000000       0.000000
# 25%       24.000000      0.000000    4403.452250    4398.823000    5669.298000
# 50%       31.000000      0.000000   15123.580000   14557.110000   16421.975000
# 75%       42.000000      1.000000   23584.180000   22923.737500   25564.670000
# max       55.000000      1.000000   25862.320000   25243.550000   25564.670000

# %% [markdown]
# > Age is vary from 16 to 55

# %%
a=['Eduacation','Race','Hisp','MaritalStatus']

# %%
for i in a:
    print(i)
    print(lab[i].value_counts())
    print()
# Out:
# Eduacation
# HighSchool            6252
# LessThanHighSchool    4731
# Intermediate          2708
# graduate              1367
# PostGraduate           934
# Name: Eduacation, dtype: int64
#
# Race
# NotBlack    14816
# black        1176
# Name: Race, dtype: int64
#
# Hisp
# NotHispanic    14840
# hispanic        1152
# Name: Hisp, dtype: int64
#
# MaritalStatus
# Married       11382
# NotMarried     4610
# Name: MaritalStatus, dtype: int64

# %%
lab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15992 entries, 0 to 15991
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            15992 non-null  int64
#  1   Eduacation     15992 non-null  object
#  2   Race           15992 non-null  object
#  3   Hisp           15992 non-null  object
#  4   MaritalStatus  15992 non-null  object
#  5   Nodeg          15992 non-null  int64
#  6   Earnings_1974  15992 non-null  float64
#  7   Earnings_1975  15992 non-null  float64
#  8   Earnings_1978  15992 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
sns.pairplot(lab)

# %%
sns.pairplot(lab,x_vars=['Age','Earnings_1974','Earnings_1975'],y_vars='Earnings_1978')

# %%
sns.distplot(lab['Earnings_1974'],color='green',kde=False)
# Out:
# D:\Installation\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Earnings_1974'>

# %%
sns.distplot(lab['Earnings_1974'],color='yellow',kde=False)
# Out:
# <AxesSubplot:xlabel='Earnings_1974'>

# %%
sns.distplot(lab['Age'],color='red',kde=False,bins=20)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(y='Age',data=lab,color='orange')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(y='Earnings_1975',data=lab,x='MaritalStatus',palette='rainbow'  )
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Earnings_1975'>

# %%
sns.boxplot(y='Earnings_1974',data=lab,color='red')
# Out:
# <AxesSubplot:ylabel='Earnings_1974'>

# %%
sns.boxplot(y='Earnings_1978',data=lab,color='black',x='MaritalStatus',palette='rainbow')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Earnings_1978'>

# %%
sns.violinplot(x=lab['MaritalStatus'],y=lab['Earnings_1978'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Earnings_1978'>

# %%
sns.boxplot(y='Earnings_1978',data=lab,color='black',x='Eduacation',palette='rainbow',width=0.5)
# Out:
# <AxesSubplot:xlabel='Eduacation', ylabel='Earnings_1978'>

# %%
sns.violinplot(x=lab['Eduacation'],y=lab['Earnings_1978'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Eduacation', ylabel='Earnings_1978'>

# %%
sns.boxplot(y='Earnings_1978',data=lab,color='black',x='Nodeg',palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Nodeg', ylabel='Earnings_1978'>

# %%
sns.violinplot(x=lab['Nodeg'],y=lab['Earnings_1978'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Nodeg', ylabel='Earnings_1978'>

# %%
sns.violinplot(x=lab['Race'],y=lab['Earnings_1978'])
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Earnings_1978'>

# %% [markdown]
# Here we can Observe that there is Much variation in Not Black

# %%
sns.boxplot(y='Earnings_1978',data=lab,color='black',x='Race',palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Earnings_1978'>

# %% [markdown]
# Median Earning Race in NotBlack is More than Black

# %%
sns.boxplot(y='Earnings_1978',data=lab,x='Hisp')
# Out:
# <AxesSubplot:xlabel='Hisp', ylabel='Earnings_1978'>

# %%
sns.violinplot(y=lab['Hisp'],x=lab['Earnings_1978'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Earnings_1978', ylabel='Hisp'>

# %%
sns.distplot(lab['Earnings_1978'])
# Out:
# D:\Installation\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Earnings_1978', ylabel='Density'>

# %% [markdown]
# <b>This is bold text <b> Yep

# %% [markdown]
# <p> &radic;600

# %% [markdown]
# <p> &infin;</p>

# %% [markdown]
# <i>This is italic text <i>

# %% [markdown]
# **Now Check for Any Correlation Between Numeric Variables
#
# >This is good
# <blockquote>
#     What is this </blockquote>

# %%
lab.corr()
# Out:
#                     Age     Nodeg  Earnings_1974  Earnings_1975  Earnings_1978
# Age            1.000000  0.052376       0.407500       0.349839       0.154274
# Nodeg          0.052376  1.000000      -0.163768      -0.176385      -0.151943
# Earnings_1974  0.407500 -0.163768       1.000000       0.870181       0.639334
# Earnings_1975  0.349839 -0.176385       0.870181       1.000000       0.668310
# Earnings_1978  0.154274 -0.151943       0.639334       0.668310       1.000000

# %%
sns.heatmap(lab.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  ## Creation of Dummy Variable

# %%
lab_dummy=pd.get_dummies(lab[['Race','Hisp','MaritalStatus','Eduacation']])
lab_dummy
# Out:
#        Race_NotBlack  Race_black  Hisp_NotHispanic  Hisp_hispanic  \
# 0                  1           0                 1              0
# 1                  1           0                 1              0
# 2                  1           0                 1              0
# 3                  1           0                 1              0
# 4                  1           0                 1              0
# ...              ...         ...               ...            ...
# 15987              0           1                 1              0
# 15988              0           1                 1              0
# 15989              1           0                 1              0
# 15990              1           0                 1              0
# 15991              1           0                 1              0
#
#        MaritalStatus_Married  MaritalStatus_NotMarried  Eduacation_HighSchool  \
# 0                          1                         0                      0
# ...

# %%
lab_dummy.shape
# Out:
# (15992, 11)

# %%
lab_combine=pd.concat([lab,lab_dummy],axis=1)
lab_combine.sample(5)
# Out:
#        Age          Eduacation      Race         Hisp MaritalStatus  Nodeg  \
# 14537   20        Intermediate  NotBlack  NotHispanic    NotMarried      0
# 10109   34          HighSchool  NotBlack  NotHispanic       Married      0
# 960     46          HighSchool  NotBlack  NotHispanic       Married      0
# 1785    17  LessThanHighSchool  NotBlack  NotHispanic    NotMarried      1
# 4396    18          HighSchool  NotBlack  NotHispanic    NotMarried      0
#
#        Earnings_1974  Earnings_1975  Earnings_1978  Race_NotBlack  Race_black  \
# 14537       11783.03       2280.871       6268.516              1           0
# 10109       24338.01      25180.890      25564.670              1           0
# 960         25862.32      25243.550      25564.670              1           0
# 1785            0.00          0.000       8458.507              1           0
# 4396         2511.78       2390.081      20744.330              1           0
#
# ...

# %% [markdown]
# ## Step:3 Train & Test

# %%
X=lab_combine[['Age', 'Nodeg',
       'Earnings_1974', 'Earnings_1975', 'Race_NotBlack',
       'Race_black', 'Hisp_NotHispanic', 'Hisp_hispanic',
       'MaritalStatus_Married', 'MaritalStatus_NotMarried',
       'Eduacation_HighSchool', 'Eduacation_Intermediate',
       'Eduacation_LessThanHighSchool', 'Eduacation_PostGraduate',
       'Eduacation_graduate']]
y=lab['Earnings_1978']

# %% [markdown]
#  Random State is seeded so that we can Random State is 100 so we all have same results since 100 is definite number

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)
print(y_test)
X_train[:5]
# Out:
# 5337     20478.33
# 10913    25564.67
# 14233    16853.47
# 795      25564.67
# 13712    25564.67
#            ...
# 13334    25564.67
# 7816     25564.67
# 7848     23046.62
# 11355    17811.04
# 10004        0.00
# Name: Earnings_1978, Length: 4798, dtype: float64
#        Age  Nodeg  Earnings_1974  Earnings_1975  Race_NotBlack  Race_black  \
# 4321    25      0     14426.0800       10398.19              1           0
# 11958   37      1     15378.2900       15047.66              1           0
# 5991    31      0     25441.0800       25243.55              1           0
# 2554    29      0       885.5886           0.00              1           0
# 8884    35      0     23401.4800       19992.53              1           0
#
#        Hisp_NotHispanic  Hisp_hispanic  MaritalStatus_Married  \
# 4321                  1              0                      0
# 11958                 1              0                      1
# 5991                  1              0                      1
# ...

# %%
lm=LinearRegression()

lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(X_test)
y_pred[:5]
# Out:
# array([16540.04007348, 21097.91690793, 21837.01538353, 17105.68844671,
#        24016.59282914])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
lm.score(X, y)
# Out:
# 0.4750581244953026

# %% [markdown]
# 1. 46.3% of variation in Y can be explained with help of given explanatory variables in model given
# 2. It explain proportion of variation In dependent variable that explined by independent variables
# 3. when we add other varible r2 increses
# 4. this may not describe importance of a varible

# %%
XX=lab_combine[['Age', 'Nodeg',
       'Earnings_1974', 'Earnings_1975', 'Race_NotBlack', 'Hisp_hispanic',
       'MaritalStatus_Married', 
       'Eduacation_HighSchool', 'Eduacation_Intermediate',
       'Eduacation_LessThanHighSchool', 'Eduacation_PostGraduate'
       ]]
yy=lab['Earnings_1978']

# %%
from sklearn.model_selection import train_test_split
X_trai, X_tes, y_trai, y_tes = train_test_split(XX, yy, test_size=0.3, random_state=100)
print(y_tes)
X_trai[:5]
# Out:
# 5337     20478.33
# 10913    25564.67
# 14233    16853.47
# 795      25564.67
# 13712    25564.67
#            ...
# 13334    25564.67
# 7816     25564.67
# 7848     23046.62
# 11355    17811.04
# 10004        0.00
# Name: Earnings_1978, Length: 4798, dtype: float64
#        Age  Nodeg  Earnings_1974  Earnings_1975  Race_NotBlack  Hisp_hispanic  \
# 4321    25      0     14426.0800       10398.19              1              0
# 11958   37      1     15378.2900       15047.66              1              0
# 5991    31      0     25441.0800       25243.55              1              0
# 2554    29      0       885.5886           0.00              1              0
# 8884    35      0     23401.4800       19992.53              1              0
#
#        MaritalStatus_Married  Eduacation_HighSchool  Eduacation_Intermediate  \
# 4321                       0                      1                        0
# 11958                      1                      0                        0
# ...

# %%
gr=LinearRegression()
gr.fit(X_trai,y_trai)
# Out:
# LinearRegression()

# %%
y_prd=gr.predict(X_tes)
y_prd[:5]
# Out:
# array([16540.04007347, 21097.91690793, 21837.01538353, 17105.68844671,
#        24016.59282914])

# %%
mse= mean_squared_error(y_tes,y_prd)
rmse=mean_squared_error(y_tes,y_prd,squared=False)
r_squared=r2_score(y_tes,y_prd)

# %%
print('Mean Squared Error :',mse)
print('Root Mean Squared Error :',rmse)
print('r_squared_value',r_squared)
# Out:
# Mean Squared Error : 50283398.72664977
# Root Mean Squared Error : 7091.078812610234
# r_squared_value 0.46392890870643944

# %% [markdown]
# Mean Squared Error : 50283398.726649955
# Root Mean Squared Error : 7091.078812610247
# r_squared_value 0.46392890870643744

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

X_train

## Step:4 Performing Linear Regression

from sklearn.linear_model import LinearRegression

# V=Creating Object of LinearRegression
lm=LinearRegression()

lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step:5 Evaluate Model

# %%
lm.intercept_
# Out:
# 7502.9051563759585

# %%
b=list(lm.coef_)

a=list(X_train.columns)

res = dict(zip(a, b))

pd.Series(res).to_frame('Coefficient')
# Out:
#                                Coefficient
# Age                            -105.198175
# Nodeg                          -291.754984
# Earnings_1974                     0.287449
# Earnings_1975                     0.477042
# Race_NotBlack                   455.276440
# Race_black                     -455.276440
# Hisp_NotHispanic                318.966611
# Hisp_hispanic                  -318.966611
# MaritalStatus_Married            -6.798382
# MaritalStatus_NotMarried          6.798382
# Eduacation_HighSchool          -406.999763
# Eduacation_Intermediate        -270.512443
# Eduacation_LessThanHighSchool  -291.754984
# Eduacation_PostGraduate         590.886229
# Eduacation_graduate             378.380960

# %% [markdown]
# So what we can Interprte is that Y= mx+ intercept
# Here intercept = 7502.905
# 1. Age if Increased by 1 unit then Corresponding change in 'Earning 1778' will Decrease by 105.19$ so as Age Increases Earning       Decreases.
# 2. As Race_Not Black Increase by One Unit corr change will increase in Earning by 455 $

# %% [markdown]
# ## Step : 6 Predictions

# %%
ypred=lm.predict(X_train)

# %%
from sklearn import metrics

# %% [markdown]
# print('Mean_absolute_error :',metrics.mean_absolute_error(y_,ypred))
#
# print('Mean_Squared_error :',metrics.mean_squared_error(y_,ypred))
#
# print('Root Mean_Squared_error :',metrics.mean_squared_error(y_,ypred,squared=False))
#
# from sklearn.metrics import r2_score
# print('R squared value for Multiple Linear Regression is',r2_score(y_,ypred))

# %% [markdown]
# sns.regplot(x=y,y=ypred,data= lab,color='orange')
# sns.set_theme(style="whitegrid")
# plt.show()

# %% [markdown]
# sns.residplot(x=y,y=ypred,data= lab,color='yellow',lowess=True)

# %%
XX=lab_combine[['Age', 'Nodeg',
       'Earnings_1974', 'Earnings_1975', 
       'Race_black',  'Hisp_hispanic',
       'MaritalStatus_Married', 
       'Eduacation_HighSchool', 'Eduacation_Intermediate',
       'Eduacation_LessThanHighSchool', 'Eduacation_PostGraduate',
       ]]
yy=lab['Earnings_1978']

# %%
from sklearn.model_selection import train_test_split
X__train, X__test, y__train, y__test = train_test_split(XX, yy, test_size=0.3, random_state=100)

# %%
X__train
# Out:
#        Age  Nodeg  Earnings_1974  Earnings_1975  Race_black  Hisp_hispanic  \
# 4321    25      0     14426.0800      10398.190           0              0
# 11958   37      1     15378.2900      15047.660           0              0
# 5991    31      0     25441.0800      25243.550           0              0
# 2554    29      0       885.5886          0.000           0              0
# 8884    35      0     23401.4800      19992.530           0              0
# ...    ...    ...            ...            ...         ...            ...
# 12119   48      0     25862.3200      25243.550           0              0
# 8039    31      0     16432.3700      14659.160           0              0
# 14147   48      1     23967.7100      24103.110           0              0
# 6936    33      0     22116.2000      22097.950           0              0
# 5640    30      0     11630.2100       1450.161           0              0
#
# ...

# %%
## Step:4 Performing Linear Regression

from sklearn.linear_model import LinearRegression

# V=Creating Object of LinearRegression
lmm=LinearRegression()

lmm.fit(X__train,y__train)
# Out:
# LinearRegression()

# %%
yy_pred=lmm.predict(XX)

# %%
print('Mean_absolute_error :',metrics.mean_absolute_error(yy,yy_pred))

print('Mean_Squared_error :',metrics.mean_squared_error(yy,yy_pred))

print('Root Mean_Squared_error :',metrics.mean_squared_error(yy,yy_pred,squared=False))

from sklearn.metrics import r2_score
print('R squared value for Multiple Linear Regression is',r2_score(yy,yy_pred))
# Out:
# Mean_absolute_error : 5168.665541495674
# Mean_Squared_error : 48854420.80039513
# Root Mean_Squared_error : 6989.593750740821
# R squared value for Multiple Linear Regression is 0.47505812449530294

# %% [markdown]
# Mean_absolute_error : 5168.665541495674
# Mean_Squared_error : 48854420.80039513
# Root Mean_Squared_error : 6989.593750740821
# R squared value for Multiple Linear Regression is 0.47505812449530294
# ### Check there is NO Change
# Mean_absolute_error : 5168.665541495672
# Mean_Squared_error : 48854420.80039516
# Root Mean_Squared_error : 6989.5937507408225
# R squared value for Multiple Linear Regression is 0.4750581244953026

# %% [markdown]
# ## Optional Step: Checking for P-value Using  StatsModel

# %%
import statsmodels.api as sm #This stands for Stats Model
X_train_sm= X_train
# Unlikely of SKlearn the Statsmodles do not fit a constant so we need to add Constant
X_train_sm=sm.add_constant(X_train_sm)
# Create a fitted Model in one Line
lm_1=sm.OLS(y_train,X_train_sm).fit()
# Print Coefficient
lm_1.params
# Out:
# const                            2756.169241
# Age                              -105.198175
# Nodeg                              14.486043
# Earnings_1974                       0.287449
# Earnings_1975                       0.477042
# Race_NotBlack                    1833.361060
# Race_black                        922.808181
# Hisp_NotHispanic                 1697.051231
# Hisp_hispanic                    1059.118010
# MaritalStatus_Married            1371.286239
# MaritalStatus_NotMarried         1384.883003
# Eduacation_HighSchool             205.482290
# Eduacation_Intermediate           341.969611
# Eduacation_LessThanHighSchool      14.486043
# Eduacation_PostGraduate          1203.368283
# Eduacation_graduate               990.863014
# dtype: float64

# %% [markdown]
# 1. F- statistics : Are the OLS models built significantly differnt from each other (Higher the better)
# 2. Prob(F- stats): P-value for the F-stats is define wheather F-stats Significant or not
# 3. Log-Likelihood : Is coverage close, closer the value to 0 indicates that Convergence point is nearer
# 4. AIC,BIC: Model goodnesss of fit vs Complexity
#          If the value is low indicates Model is Close to Best Fit (True  Model)
# 5. Skewness: Measure of symm of residual around mean
# 6. Kurtosis : Measure of shape of distribution of residual compare residuals that are closer vs residual that are far away from mean
# 7. Omnibus: Combine Kurtosis and Skewness and provide on estimate which is statistical in nature
# 8. Jorque bera : Different tst test for skewness and kurtosis of REsidual
# 9. Durbin-Watson: A test for the presence of auto correlation of residual and IMP in Time Series

# %%
print(lm_1.summary())

# Prob of F-stats<0.05
# Log-Likelihood must close to 0 if -ve ther is problem with l=model like there relationship 
# AIC- goodness of Fit
# BIC- 
#t=coef/std err
#P value is stat. S
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Earnings_1978   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     1031.
# Date:                Thu, 12 Aug 2021   Prob (F-statistic):               0.00
# Time:                        15:09:56   Log-Likelihood:            -1.1490e+05
# No. Observations:               11194   AIC:                         2.298e+05
# Df Residuals:                   11183   BIC:                         2.299e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2756.1692    103.746     26.566      0.000    2552.808    2959.530
# ...

# %% [markdown]
# H0 indep var is not predictable is not static signifi
# p<0.05  it is Statisically signifcant
# why?
# estimate is how strong>
# it has capa of Significant
# p> then rerun after removing

# %% [markdown]
# ## Step 8 : Implementing the results

# %%
# Actual vs Predicted
# Now lets check for 200 observations
c=[i for i in range(1,200,1)]
fig=plt.figure()
plt.plot(c,y_test[1:200],color='black',linewidth=2.5, linestyle='-')
plt.plot(c,y_pred[1:200],color='green',linewidth=2.5, linestyle='-')
fig.suptitle('Actual and Predicted',fontsize=20)
plt.xlabel("Labour",fontsize=18)
plt.ylabel('Earnings_1978',fontsize=16)
plt.show()

# %%
len(y_pred)
# Out:
# 4798

# %%
# Error terms
c=[ i for i in range(0,4798,1)]
fig=plt.figure()
plt.plot(c,y_test-y_pred,color='red',linestyle='-')
plt.suptitle('Error Terms',fontsize=20)
plt.xlabel('Index', fontsize=18)
plt.ylabel('Actual - Predicted')
# Out:
# Text(0, 0.5, 'Actual - Predicted')

# %%
print('Mean Square Error :', mse)
print('r_squared_value :',r_squared)
# Out:
# Mean Square Error : 50283398.72664977
# r_squared_value : 0.46392890870643944

# %%
X_train_final =X_train
# we need to add constant manally
X_train_final=sm.add_constant(X_train_final)
# Create a fitted model in one line
lm_final= sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Earnings_1978   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     1031.
# Date:                Thu, 12 Aug 2021   Prob (F-statistic):               0.00
# Time:                        15:09:58   Log-Likelihood:            -1.1490e+05
# No. Observations:               11194   AIC:                         2.298e+05
# Df Residuals:                   11183   BIC:                         2.299e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2756.1692    103.746     26.566      0.000    2552.808    2959.530
# ...

# %%
# Errir terms
c=[ i for i in range(0,500,1)]
fig=plt.figure()
plt.plot(c,y_test[0:500]-y_pred[0:500],color='green',linestyle='-')
plt.suptitle('Error Terms',fontsize=20)
plt.xlabel('Index', fontsize=18)
plt.ylabel('Actual - Predicted')
# Out:
# Text(0, 0.5, 'Actual - Predicted')

# %% [markdown]
# ## Varience Inflation Factor

# %% [markdown]
# Here, we take particular X as responce variable and all other explanatory
#
# Variables as independent variables So we run a regression between one of those explanatory variables with remaining variables

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X_train.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_train.values, i)
                          for i in range(len(X_train.columns))]
# Out:
# D:\Installation\Anaconda\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vif_data.round(2)
# Out:
#                           feature   VIF
# 0                             Age  1.37
# 1                           Nodeg   inf
# 2                   Earnings_1974  4.46
# 3                   Earnings_1975  4.23
# 4                   Race_NotBlack   inf
# 5                      Race_black   inf
# 6                Hisp_NotHispanic   inf
# 7                   Hisp_hispanic   inf
# 8           MaritalStatus_Married   inf
# 9        MaritalStatus_NotMarried   inf
# 10          Eduacation_HighSchool   inf
# 11        Eduacation_Intermediate   inf
# 12  Eduacation_LessThanHighSchool   inf
# 13        Eduacation_PostGraduate   inf
# 14            Eduacation_graduate   inf

# %%
[X_train.values for i in range(len(X_train))]

# %%
from sklearn.feature_selection import RFE

# %%
lm_check=LinearRegression()

# %%
rfe=RFE(lm_check,2)
# Out:
# D:\Installation\Anaconda\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_features_to_select=2 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=2)

# %%
feature_imp= pd.DataFrame({'Importance':rfe.support_,"Columns":X_train.columns})

feature_imp.sort_values(by="Importance",ascending=False)
# Out:
#     Importance                        Columns
# 1         True                          Nodeg
# 11        True        Eduacation_Intermediate
# 0        False                            Age
# 2        False                  Earnings_1974
# 3        False                  Earnings_1975
# 4        False                  Race_NotBlack
# 5        False                     Race_black
# 6        False               Hisp_NotHispanic
# 7        False                  Hisp_hispanic
# 8        False          MaritalStatus_Married
# 9        False       MaritalStatus_NotMarried
# 10       False          Eduacation_HighSchool
# 12       False  Eduacation_LessThanHighSchool
# 13       False        Eduacation_PostGraduate
# 14       False            Eduacation_graduate
